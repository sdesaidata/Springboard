# %% [markdown]
# # Word Cloud
# ***

# %% [markdown]
# ### Import and Review Data
# ***

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
from wordcloud import WordCloud
import pickle
from nltk.tokenize import word_tokenize
import nltk

# %%
with open('beerML.pickle', 'rb') as b:
    beer = pickle.load(b)

# %% [markdown]
# ### Determine Word Count per Review
# ***
# To create more quantitative features, lets determine the word count for each text review

# %%
# Determine the word count for each text review: word_count
beer['word_count'] = beer['clean_text_lem'].apply(lambda x: len(str(x).split(" ")))

# %% [markdown]
# ### All Beers

# %%
from PIL import Image
import urllib
import requests
from wordcloud import WordCloud, ImageColorGenerator
from os import path, getcwd

# %%
d = getcwd()
## join all documents in corpus
## image from PublicDomainPictures.net
## http://www.publicdomainpictures.net/view-image.php?image=232185&picture=family-gathering
mask = np.array(Image.open(path.join(d, "beer.png")))
wc = WordCloud(background_color="white", max_words=1000, mask=mask,
               random_state=42, width = 400, height = 400, max_font_size=90)
wc.generate(words)
# create coloring from image
image_colors = ImageColorGenerator(mask)
plt.figure(figsize=[10,7])
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")
plt.axis("off")
_=plt.show()
